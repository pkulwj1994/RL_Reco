# %%
# !git clone https://github.com/pkulwj1994/RL_Reco.git
# Out:
# Cloning into 'RL_Reco'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 37 (delta 7), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (37/37), done.

# %%
# !cp -a /content/RL_Reco/. /content/.

# %%
import os
if os.path.exists('/content/drive/MyDrive/RL_Reco'):
  pass
else:
  os.mkdir('/content/drive/MyDrive/RL_Reco')

base_dir = '/content/drive/MyDrive/RL_Reco'

if os.path.exists(os.path.join(base_dir,'save_weights')):
  pass
else:
  os.mkdir(os.path.join(base_dir,'save_weights'))

if os.path.exists(os.path.join(base_dir,'data')):
  pass
else:
  os.mkdir(os.path.join(base_dir,'data'))


if os.path.exists(os.path.join(base_dir,'images')):
  pass
else:
  os.mkdir(os.path.join(base_dir,'images'))

# %%
# !pip install wandb
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 97 kB 8.9 MB/s
# ...
#      |████████████████████████████████| 142 kB 69.3 MB/s
# ...
#      |████████████████████████████████| 180 kB 62.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.2 MB/s
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=aa220a68db7bab4aa3c0d3382169f8501d4c1dcc268fa74b6980285f35dbb934
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=9d01cd7d7d800c97148e4645b0d724cbfba1f7f18bb6f2a93fc303474d36082d
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built subprocess32 pathtools
# ...

# %%
# !wget https://files.grouplens.org/datasets/movielens/ml-1m.zip
# !unzip ./ml-1m.zip
# Out:
# --2022-01-21 09:49:28--  https://files.grouplens.org/datasets/movielens/ml-1m.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5917549 (5.6M) [application/zip]
# Saving to: ‘ml-1m.zip’
#
# ml-1m.zip           100%[===================>]   5.64M  18.8MB/s    in 0.3s
#
# 2022-01-21 09:49:29 (18.8 MB/s) - ‘ml-1m.zip’ saved [5917549/5917549]
#
# Archive:  ./ml-1m.zip
#    creating: ml-1m/
#   inflating: ml-1m/movies.dat
#   inflating: ml-1m/ratings.dat
#   inflating: ml-1m/README
#   inflating: ml-1m/users.dat

# %%
# !python train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# recommended items : 20,  epsilon : 0.880, reward : +2
# 875/8000, precision : 20%, total_reward:0.0, q_loss : 7.236290548462421e-05, mean_action : 0.039048755168914796
# recommended items : 88,  epsilon : 0.879, reward : +1
# 876/8000, precision : 17%, total_reward:-12.0, q_loss : 7.762027235003188e-05, mean_action : -0.012028073966503147
# recommended items : 29,  epsilon : 0.879, reward : -0.5
# 877/8000, precision :  0%, total_reward:-9.5, q_loss : 7.879192708060145e-05, mean_action : -0.022174864442724932
# recommended items : 181,  epsilon : 0.879, reward : -0.5
# 878/8000, precision : 36%, total_reward:45.0, q_loss : 7.468735566362739e-05, mean_action : -0.03464410546927425
# recommended items : 129,  epsilon : 0.879, reward : +0
# 879/8000, precision : 35%, total_reward:25.5, q_loss : 8.359982894035056e-05, mean_action : -0.05315148463770121
# recommended items : 72,  epsilon : 0.879, reward : -0.5
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !zip -r /content/RL_Reco.zip /content/Recommender_system_via_deep_RL
# Out:
# updating: content/Recommender_system_via_deep_RL/ (stored 0%)
#   adding: content/Recommender_system_via_deep_RL/recommender.py (deflated 73%)
#   adding: content/Recommender_system_via_deep_RL/.gitignore (deflated 47%)
#   adding: content/Recommender_system_via_deep_RL/README.md (deflated 46%)
#   adding: content/Recommender_system_via_deep_RL/state_representation.py (deflated 59%)
#   adding: content/Recommender_system_via_deep_RL/critic.py (deflated 71%)
#   adding: content/Recommender_system_via_deep_RL/tree.py (deflated 80%)
#   adding: content/Recommender_system_via_deep_RL/embedding.py (deflated 83%)
#   adding: content/Recommender_system_via_deep_RL/replay_buffer.py (deflated 73%)
#   adding: content/Recommender_system_via_deep_RL/embed_ids.ipynb (deflated 75%)
#   adding: content/Recommender_system_via_deep_RL/envs.py (deflated 75%)
#   adding: content/Recommender_system_via_deep_RL/actor.py (deflated 67%)
# ...
